# %%
import os
import requests
from bs4 import BeautifulSoup
import pandas as pd

# GitHub raw URL base
github_url = "https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data/csse_covid_19_daily_reports"
raw_base_url = "https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/"

# Create a directory to store downloaded files
os.makedirs("covid_data", exist_ok=True)

# Get the list of CSV files from the GitHub directory
response = requests.get(github_url)
soup = BeautifulSoup(response.text, 'html.parser')

csv_files = [
    link.text for link in soup.find_all('a', href=True)
    if link.text.endswith(".csv")
]

# Download each CSV file
for csv_file in csv_files:
    file_url = raw_base_url + csv_file
    file_path = os.path.join("covid_data", csv_file)
    
    print(f"Downloading {csv_file}...")
    
    response = requests.get(file_url)
    if response.status_code == 200:
        with open(file_path, "wb") as f:
            f.write(response.content)
    else:
        print(f"Failed to download {csv_file}")

print("All files downloaded.")

# Load all CSV files into a single DataFrame
all_cases = []
for csv_file in csv_files:
    file_path = os.path.join("covid_data", csv_file)
    df = pd.read_csv(file_path, sep=",")
    df["Date"] = csv_file.replace(".csv", "")  # Extract date from filename
    all_cases.append(df)

# Concatenate all DataFrames
cases = pd.concat(all_cases, ignore_index=True)

# Save merged dataset
cases.to_csv("covid_data/merged_cases.csv", index=False)
print("Merged dataset saved as covid_data/merged_cases.csv")
# Out:
# Downloading 01-01-2021.csv...
# Downloading 01-01-2021.csv...
# Downloading 01-01-2022.csv...
# Downloading 01-01-2022.csv...
# Downloading 01-01-2023.csv...
# Downloading 01-01-2023.csv...
# Downloading 01-02-2021.csv...
# Downloading 01-02-2021.csv...
# Downloading 01-02-2022.csv...
# Downloading 01-02-2022.csv...
# Downloading 01-02-2023.csv...
# Downloading 01-02-2023.csv...
# Downloading 01-03-2021.csv...
# Downloading 01-03-2021.csv...
# Downloading 01-03-2022.csv...
# Downloading 01-03-2022.csv...
# Downloading 01-03-2023.csv...
# Downloading 01-03-2023.csv...
# Downloading 01-04-2021.csv...
# Downloading 01-04-2021.csv...
# Downloading 01-04-2022.csv...
# Downloading 01-04-2022.csv...
# Downloading 01-04-2023.csv...
# Downloading 01-04-2023.csv...
# Downloading 01-05-2021.csv...
# Downloading 01-05-2021.csv...
# Downloading 01-05-2022.csv...
# Downloading 01-05-2022.csv...
# Downloading 01-05-2023.csv...
# Downloading 01-05-2023.csv...
# Downloading 01-06-2021.csv...
# Downloading 01-06-2021.csv...
# Downloading 01-06-2022.csv...
# Downloading 01-06-2022.csv...
# Downloading 01-06-2023.csv...
# Downloading 01-06-2023.csv...
# Downloading 01-07-2021.csv...
# Downloading 01-07-2021.csv...
# Downloading 01-07-2022.csv...
# Downloading 01-07-2022.csv...
# Downloading 01-07-2023.csv...
# Downloading 01-07-2023.csv...
# Downloading 01-08-2021.csv...
# Downloading 01-08-2021.csv...
# Downloading 01-08-2022.csv...
# Downloading 01-08-2022.csv...
# Downloading 01-08-2023.csv...
# Downloading 01-08-2023.csv...
# Downloading 01-09-2021.csv...
# Downloading 01-09-2021.csv...
# Downloading 01-09-2022.csv...
# Downloading 01-09-2022.csv...
# Downloading 01-09-2023.csv...
# Downloading 01-09-2023.csv...
# Downloading 01-10-2021.csv...
# Downloading 01-10-2021.csv...
# Downloading 01-10-2022.csv...
# Downloading 01-10-2022.csv...
# Downloading 01-10-2023.csv...
# Downloading 01-10-2023.csv...
# Downloading 01-11-2021.csv...
# Downloading 01-11-2021.csv...
# Downloading 01-11-2022.csv...
# Downloading 01-11-2022.csv...
# Downloading 01-11-2023.csv...
# Downloading 01-11-2023.csv...
# Downloading 01-12-2021.csv...
# Downloading 01-12-2021.csv...
# Downloading 01-12-2022.csv...
# Downloading 01-12-2022.csv...
# Downloading 01-12-2023.csv...
# Downloading 01-12-2023.csv...
# Downloading 01-13-2021.csv...
# Downloading 01-13-2021.csv...
# Downloading 01-13-2022.csv...
# Downloading 01-13-2022.csv...
# Downloading 01-13-2023.csv...
# Downloading 01-13-2023.csv...
# Downloading 01-14-2021.csv...
# Downloading 01-14-2021.csv...
# Downloading 01-14-2022.csv...
# Downloading 01-14-2022.csv...
# Downloading 01-14-2023.csv...
# Downloading 01-14-2023.csv...
# Downloading 01-15-2021.csv...
# Downloading 01-15-2021.csv...
# Downloading 01-15-2022.csv...
# Downloading 01-15-2022.csv...
# Downloading 01-15-2023.csv...
# Downloading 01-15-2023.csv...
# Downloading 01-16-2021.csv...
# Downloading 01-16-2021.csv...
# Downloading 01-16-2022.csv...
# Downloading 01-16-2022.csv...
# Downloading 01-16-2023.csv...
# Downloading 01-16-2023.csv...
# Downloading 01-17-2021.csv...
# Downloading 01-17-2021.csv...
# Downloading 01-17-2022.csv...
# Downloading 01-17-2022.csv...
# Downloading 01-17-2023.csv...
# Downloading 01-17-2023.csv...
# Downloading 01-18-2021.csv...
# Downloading 01-18-2021.csv...
# Downloading 01-18-2022.csv...
# Downloading 01-18-2022.csv...
# Downloading 01-18-2023.csv...
# Downloading 01-18-2023.csv...
# Downloading 01-19-2021.csv...
# Downloading 01-19-2021.csv...
# Downloading 01-19-2022.csv...
# Downloading 01-19-2022.csv...
# Downloading 01-19-2023.csv...
# Downloading 01-19-2023.csv...
# Downloading 01-20-2021.csv...
# Downloading 01-20-2021.csv...
# Downloading 01-20-2022.csv...
# Downloading 01-20-2022.csv...
# Downloading 01-20-2023.csv...
# Downloading 01-20-2023.csv...
# Downloading 01-21-2021.csv...
# Downloading 01-21-2021.csv...
# Downloading 01-21-2022.csv...
# Downloading 01-21-2022.csv...
# Downloading 01-21-2023.csv...
# Downloading 01-21-2023.csv...
# Downloading 01-22-2020.csv...
# Downloading 01-22-2020.csv...
# Downloading 01-22-2021.csv...
# Downloading 01-22-2021.csv...
# Downloading 01-22-2022.csv...
# Downloading 01-22-2022.csv...
# Downloading 01-22-2023.csv...
# Downloading 01-22-2023.csv...
# Downloading 01-23-2020.csv...
# Downloading 01-23-2020.csv...
# Downloading 01-23-2021.csv...
# Downloading 01-23-2021.csv...
# Downloading 01-23-2022.csv...
# Downloading 01-23-2022.csv...
# Downloading 01-23-2023.csv...
# Downloading 01-23-2023.csv...
# Downloading 01-24-2020.csv...
# Downloading 01-24-2020.csv...
# Downloading 01-24-2021.csv...
# Downloading 01-24-2021.csv...
# Downloading 01-24-2022.csv...
# Downloading 01-24-2022.csv...
# Downloading 01-24-2023.csv...
# Downloading 01-24-2023.csv...
# Downloading 01-25-2020.csv...
# Downloading 01-25-2020.csv...
# Downloading 01-25-2021.csv...
# Downloading 01-25-2021.csv...
# Downloading 01-25-2022.csv...
# Downloading 01-25-2022.csv...
# Downloading 01-25-2023.csv...
# Downloading 01-25-2023.csv...
# Downloading 01-26-2020.csv...
# Downloading 01-26-2020.csv...
# Downloading 01-26-2021.csv...
# Downloading 01-26-2021.csv...
# Downloading 01-26-2022.csv...
# Downloading 01-26-2022.csv...
# Downloading 01-26-2023.csv...
# Downloading 01-26-2023.csv...
# Downloading 01-27-2020.csv...
# Downloading 01-27-2020.csv...
# Downloading 01-27-2021.csv...
# Downloading 01-27-2021.csv...
# Downloading 01-27-2022.csv...
# Downloading 01-27-2022.csv...
# Downloading 01-27-2023.csv...
# Downloading 01-27-2023.csv...
# Downloading 01-28-2020.csv...
# Downloading 01-28-2020.csv...
# Downloading 01-28-2021.csv...
# Downloading 01-28-2021.csv...
# Downloading 01-28-2022.csv...
# Downloading 01-28-2022.csv...
# Downloading 01-28-2023.csv...
# Downloading 01-28-2023.csv...
# Downloading 01-29-2020.csv...
# Downloading 01-29-2020.csv...
# Downloading 01-29-2021.csv...
# Downloading 01-29-2021.csv...
# Downloading 01-29-2022.csv...
# Downloading 01-29-2022.csv...
# Downloading 01-29-2023.csv...
# Downloading 01-29-2023.csv...
# Downloading 01-30-2020.csv...
# Downloading 01-30-2020.csv...
# Downloading 01-30-2021.csv...
# Downloading 01-30-2021.csv...
# Downloading 01-30-2022.csv...
# Downloading 01-30-2022.csv...
# Downloading 01-30-2023.csv...
# Downloading 01-30-2023.csv...
# All files downloaded.
# Merged dataset saved as covid_data/merged_cases.csv
